# %%
import math
import numpy as np
import pandas as pd

def density(df):
    den_tot = []

    for attr in df.columns:

        n_distinct = df[attr].nunique()
        prob_attr = []
        den_attr = 0

        for item in df[attr].unique():
            p_attr = len(df[df[attr] == item])/len(df)
            prob_attr.append(p_attr)

        avg_den_attr = 1/n_distinct

        for p in prob_attr:
            den_attr += math.sqrt((p - avg_den_attr) ** 2)
            den_attr = den_attr/n_distinct

        den_tot.append(den_attr*100)

    return den_tot

def entropy(df):
    en_tot = []

    for attr in df.columns:

        prob_attr = []

        for item in df[attr].unique():
            p_attr = len(df[df[attr] == item])/len(df)
            prob_attr.append(p_attr)

        en_attr = 0

        if 0 in prob_attr:
            prob_attr.remove(0)

        for p in prob_attr:
            en_attr += p*np.log(p)
        en_attr = -en_attr

        en_tot.append(en_attr)

    return en_tot

def correlations(df):
    p_corr = 0

    num = list(df.select_dtypes(include=['int64','float64']).columns)

    corr = df[num].corr()

    if len(num) != 0:
        for c in corr.columns:
            a = (corr[c] > 0.7).sum() - 1
            if a > 0:
                p_corr += 1

        p_corr = p_corr / len(corr.columns)

        return round(p_corr,4),round(corr.replace(1,0).max().max(),4),round(corr.min().min(),4)

    else:
        return np.nan,np.nan,np.nan


def import_features_2(df):

    num = len(list(df.select_dtypes(include=['int64','float64']).columns))
    cat = len(list(df.select_dtypes(include=['bool','object']).columns))

    rows = df.shape[0]

    cols = df.shape[1]

    den = density(df)
    en = entropy(df)
    corr = correlations(df)

    return rows,cols,round(num/cols,2),round(cat/cols,2),round(df.duplicated().sum()/rows,4),df.memory_usage().sum(),\
           round(df.nunique().mean()/rows,4),round(df.nunique().max()/rows,4),round(df.nunique().min()/rows,4),\
           round(sum(den)/len(den),4),round(max(den),4),round(min(den),4),\
           round(sum(en)/len(en),4),round(max(en),4),round(min(en),4),\
           corr[0],corr[1],corr[2]

def import_data_features_2(name, df):

    with open(name+"_features.csv", "w") as file:
        file.write("name,n_tuples,n_attributes,p_num_var,p_cat_var,p_duplicates,total_size,"+
                   "p_avg_distinct,p_max_distinct,p_min_distinct,"+
                   "avg_density,max_density,min_density,"+
                   "avg_entropy,max_entropy,min_entropy,"+
                   "p_correlated_features,max_pearson,min_pearson,"+
                   "\n")

        features = str(import_features_2(df))
        features = features.replace("(", "")
        features = features.replace(")", "")
        features = features.replace(" ", "")
        file.write(name+","+features+"\n")

    file_path = name+"_features.csv"
    data_features = pd.read_csv(file_path)

    return data_features

def import_data_features_dataframe(name, df):

    features = import_features_2(df,name)
    #features = features.replace("(", "")
    #features = features.replace(")", "")
    #features = features.replace(" ", "")

    data_features = pd.DataFrame(
        [features],columns=["name","n_tuples","n_attributes","p_num_var","p_cat_var","p_duplicates","total_size",
                   "p_avg_distinct","p_max_distinct","p_min_distinct",
                   "avg_density","max_density","min_density",
                   "avg_entropy","max_entropy","min_entropy",
                   "p_correlated_features","max_pearson","min_pearson"]
    )

    return data_features

def density_single_column(df, column):

    n_distinct = df[column].nunique()
    prob_attr = []
    den_attr = 0

    for item in df[column].unique():
        p_attr = len(df[df[column] == item])/len(df)
        prob_attr.append(p_attr)

    avg_den_attr = 1/n_distinct

    for p in prob_attr:
        den_attr += math.sqrt((p - avg_den_attr) ** 2)
        den_attr = den_attr/n_distinct

    return den_attr*100


def entropy_single_column(df, column):

    prob_attr = []

    for item in df[column].unique():
        p_attr = len(df[df[column] == item])/len(df)
        prob_attr.append(p_attr)

    en_attr = 0

    if 0 in prob_attr:
        prob_attr.remove(0)

    for p in prob_attr:
        en_attr += p*np.log(p)
    en_attr = -en_attr

    return en_attr


def import_features_single_column(df, column, name, stringa):
    num = len(list(df.select_dtypes(include=['int64', 'float64']).columns))
    cat = len(list(df.select_dtypes(include=['bool', 'object']).columns))

    rows = df.shape[0]

    cols = df.shape[1]

    # qua stava den e en = 0 e stava commentato density e entropy
    # den = [0]#density(df)
    # en = [0]#entropy(df)
    den = density_single_column(df, column)
    en = entropy_single_column(df, column)
    corr = correlations(df)

    den_df = density(df)
    en_df = entropy(df)

    if df[column].dtype == 'float64' or df[column].dtype == 'int64':
        column_type = "numerical"
    else:
        column_type = "categorical"

    return name, stringa, rows, cols,round(df.nunique().mean()/rows,4),round(df.nunique().max()/rows,4),round(df.nunique().min()/rows,4),round(sum(den_df)/len(den_df),4),round(max(den_df),4),round(min(den_df),4),round(sum(en_df)/len(en_df),4),round(max(en_df),4),round(min(en_df),4),round(num / cols, 2), round(cat / cols, 2), round(df.duplicated().sum()/ rows, 4),df.memory_usage().sum(), round(df[column].nunique() / rows, 4), round(den, 4),round(en, 4),corr[0], corr[1], corr[2], column_type


def import_features_complete(df):


    num = len(list(df.select_dtypes(include=['int64','float64']).columns))
    cat = len(list(df.select_dtypes(include=['bool','object']).columns))

    rows = df.shape[0]

    cols = df.shape[1]

    den = density(df)
    en = entropy(df)
    corr = correlations(df)

    return rows,cols,round(num/cols,2),round(cat/cols,2),round(df.duplicated().sum()/rows,4),df.memory_usage().sum(),\
           round(df.nunique().mean()/rows,4),round(df.nunique().max()/rows,4),round(df.nunique().min()/rows,4), \
           round(sum(den)/len(den),4),round(max(den),4),round(min(den),4),\
           round(sum(en)/len(en),4),round(max(en),4),round(min(en),4),\
           corr[0],corr[1],corr[2]

# %%
#names = ["acusticFS","cancerFS","ecoliFS","frogsFS","letterFS","oilFS","qualityredFS","qualitywhiteFS"]
names = ['letter_Dirty10_1','letter_Dirty20_1','letter_Dirty30_1','letter_Dirty40_1','letter_Dirty50_1']
labels1 = ['x-ege', 'y2bar','y-ege','xy2br']
i = 10

with open("/Users/martinacaffagnini/Tesi/CodiceTesi/datasets/single_column.csv", "w") as file:
    file.write("name,column_name, n_tuples, n_attributes,p_avg_distinct,p_max_distinct,p_min_distinct,avg_density,max_density,min_density,avg_entropy,max_entropy,min_entropy,p_num_var,p_cat_var,p_duplicates,total_size,column_uniqueness,column_density,column_entropy,p_correlated_features,max_pearson,min_pearson,column_type"
                "\n")
    


                   
    
    for name in names:
        for column in labels1:
            #print(column)
            file_path = "/Users/martinacaffagnini/Tesi/CodiceTesi/datasets_dirty/"+name+ ".csv"
            df = pd.read_csv(file_path)
            df = df.drop(columns=['letter'])
            stringa = column+'_'+str(i)
            features = str(import_features_single_column(df, column, 'letter', stringa))
            features = features.replace("(", "")
            features = features.replace(")", "")
            features = features.replace(" ", "")
            file.write(features+"\n")
        i = i+10

# %%
prova = pd.read_csv('/Users/martinacaffagnini/Tesi/CodiceTesi/datasets/single_column.csv')

# %%
prova
# Out:
#         name column_name   n_tuples   n_attributes  p_avg_distinct
# 0   'letter'  'x-ege_10'       2001              4          0.1064  \
# 1   'letter'  'y2bar_10'       2001              4          0.1064
# 2   'letter'  'y-ege_10'       2001              4          0.1064
# 3   'letter'  'xy2br_10'       2001              4          0.1064
# 4   'letter'  'x-ege_20'       2001              4          0.2128
# 5   'letter'  'y2bar_20'       2001              4          0.2128
# 6   'letter'  'y-ege_20'       2001              4          0.2128
# 7   'letter'  'xy2br_20'       2001              4          0.2128
# 8   'letter'  'x-ege_30'       2001              4          0.3187
# 9   'letter'  'y2bar_30'       2001              4          0.3187
# 10  'letter'  'y-ege_30'       2001              4          0.3187
# 11  'letter'  'xy2br_30'       2001              4          0.3187
# 12  'letter'  'x-ege_40'       2001              4          0.4015
# 13  'letter'  'y2bar_40'       2001              4          0.4015
# 14  'letter'  'y-ege_40'       2001              4          0.4015
# 15  'letter'  'xy2br_40'       2001              4          0.4015
# 16  'letter'  'x-ege_50'       2001              4          0.5036
# 17  'letter'  'y2bar_50'       2001              4          0.5036
# 18  'letter'  'y-ege_50'       2001              4          0.5036
# 19  'letter'  'xy2br_50'       2001              4          0.5036
#
#     p_max_distinct  p_min_distinct  avg_density  max_density  min_density
# 0           0.1149          0.1004       0.0020       0.0022       0.0017  \
# 1           0.1149          0.1004       0.0020       0.0022       0.0017
# 2           0.1149          0.1004       0.0020       0.0022       0.0017
# 3           0.1149          0.1004       0.0020       0.0022       0.0017
# 4           0.2289          0.1944       0.0004       0.0005       0.0004
# 5           0.2289          0.1944       0.0004       0.0005       0.0004
# 6           0.2289          0.1944       0.0004       0.0005       0.0004
# 7           0.2289          0.1944       0.0004       0.0005       0.0004
# 8           0.3218          0.3108       0.0002       0.0002       0.0002
# 9           0.3218          0.3108       0.0002       0.0002       0.0002
# 10          0.3218          0.3108       0.0002       0.0002       0.0002
# 11          0.3218          0.3108       0.0002       0.0002       0.0002
# 12          0.4133          0.3938       0.0001       0.0001       0.0001
# 13          0.4133          0.3938       0.0001       0.0001       0.0001
# 14          0.4133          0.3938       0.0001       0.0001       0.0001
# 15          0.4133          0.3938       0.0001       0.0001       0.0001
# 16          0.5232          0.4893       0.0000       0.0001       0.0000
# 17          0.5232          0.4893       0.0000       0.0001       0.0000
# 18          0.5232          0.4893       0.0000       0.0001       0.0000
# 19          0.5232          0.4893       0.0000       0.0001       0.0000
#
#     ...  p_cat_var  p_duplicates  total_size  column_uniqueness
# 0   ...        0.0        0.2519       64160             0.1149  \
# 1   ...        0.0        0.2519       64160             0.1059
# 2   ...        0.0        0.2519       64160             0.1044
# 3   ...        0.0        0.2519       64160             0.1004
# 4   ...        0.0        0.1144       64160             0.2189
# 5   ...        0.0        0.1144       64160             0.2289
# 6   ...        0.0        0.1144       64160             0.1944
# 7   ...        0.0        0.1144       64160             0.2089
# 8   ...        0.0        0.0410       64160             0.3108
# 9   ...        0.0        0.0410       64160             0.3218
# 10  ...        0.0        0.0410       64160             0.3203
# 11  ...        0.0        0.0410       64160             0.3218
# 12  ...        0.0        0.0130       64160             0.4003
# 13  ...        0.0        0.0130       64160             0.4133
# 14  ...        0.0        0.0130       64160             0.3988
# 15  ...        0.0        0.0130       64160             0.3938
# 16  ...        0.0        0.0045       64160             0.4893
# 17  ...        0.0        0.0045       64160             0.5092
# 18  ...        0.0        0.0045       64160             0.5232
# 19  ...        0.0        0.0045       64160             0.4928
#
#     column_density  column_entropy  p_correlated_features  max_pearson
# 0           0.0017          2.7787                    0.0       0.0257  \
# 1           0.0020          2.8685                    0.0       0.0257
# 2           0.0021          2.8500                    0.0       0.0257
# 3           0.0022          2.6751                    0.0       0.0257
# 4           0.0004          3.4353                    0.0       0.0472
# 5           0.0004          3.6253                    0.0       0.0472
# 6           0.0005          3.4027                    0.0       0.0472
# 7           0.0005          3.3695                    0.0       0.0472
# 8           0.0002          4.0245                    0.0       0.0437
# 9           0.0002          4.1888                    0.0       0.0437
# 10          0.0002          4.1761                    0.0       0.0437
# 11          0.0002          4.0912                    0.0       0.0437
# 12          0.0001          4.5522                    0.0       0.0275
# 13          0.0001          4.7232                    0.0       0.0275
# 14          0.0001          4.6467                    0.0       0.0275
# 15          0.0001          4.5317                    0.0       0.0275
# 16          0.0001          5.0942                    0.0       0.0382
# 17          0.0000          5.2962                    0.0       0.0382
# 18          0.0000          5.3586                    0.0       0.0382
# 19          0.0001          5.0998                    0.0       0.0382
#
#     min_pearson  column_type
# 0       -0.0142  'numerical'
# 1       -0.0142  'numerical'
# 2       -0.0142  'numerical'
# 3       -0.0142  'numerical'
# 4       -0.0059  'numerical'
# 5       -0.0059  'numerical'
# 6       -0.0059  'numerical'
# 7       -0.0059  'numerical'
# 8       -0.0154  'numerical'
# 9       -0.0154  'numerical'
# 10      -0.0154  'numerical'
# 11      -0.0154  'numerical'
# 12      -0.0313  'numerical'
# 13      -0.0313  'numerical'
# 14      -0.0313  'numerical'
# 15      -0.0313  'numerical'
# 16      -0.0453  'numerical'
# 17      -0.0453  'numerical'
# 18      -0.0453  'numerical'
# 19      -0.0453  'numerical'
#
# [20 rows x 24 columns]
