# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = "../../Risultati/Chlorine/outlier_detection.csv"
df = pd.read_csv(path)
df.reset_index(drop=True)
df['percentage'] = 100 - df['percentage']
df
# Out:
#      percentage   method  precision    recall        f1
# 0            90        z   0.098235  1.000000  0.178896
# 1            90      lof   0.753846  0.926714  0.831389
# 2            90  iforest   0.139505  0.252955  0.179832
# 3            90      hst   0.091925  0.427896  0.151338
# 4            90        z   0.100557  1.000000  0.182739
# ..          ...      ...        ...       ...       ...
# 155          50      hst   0.531627  0.163124  0.249646
# 156          50        z   0.498954  0.999534  0.665633
# 157          50      lof   0.953302  0.940875  0.947048
# 158          50  iforest   0.665359  0.236965  0.349468
# 159          50      hst   0.508431  0.182495  0.268585
#
# [160 rows x 5 columns]

# %%
df_z = df[(df['method'] == 'z')].groupby(['percentage']).mean(numeric_only=True).reset_index()
df_z
# Out:
#    percentage  precision    recall        f1
# 0          50   0.501162  0.999654  0.667589
# 1          60   0.399998  0.999852  0.571373
# 2          70   0.299205  0.999906  0.460564
# 3          80   0.203176  0.999424  0.337664
# 4          90   0.099135  0.999704  0.180371

# %%
df_lof = df[(df['method'] == 'lof')].groupby(['percentage']).mean(numeric_only=True).reset_index()
df_lof
# Out:
#    percentage  precision    recall        f1
# 0          50   0.953304  0.932460  0.942759
# 1          60   0.939954  0.937283  0.938611
# 2          70   0.912638  0.938976  0.925607
# 3          80   0.871668  0.939519  0.904314
# 4          90   0.756651  0.939802  0.838304

# %%
df_if = df[(df['method'] == 'iforest')].groupby(['percentage']).mean(numeric_only=True).reset_index()
df_if
# Out:
#    percentage  precision    recall        f1
# 0          50   0.652424  0.238799  0.349550
# 1          60   0.532696  0.247609  0.338001
# 2          70   0.415215  0.254710  0.315697
# 3          80   0.285351  0.250990  0.266954
# 4          90   0.138975  0.250553  0.178709

# %%
df_hst = df[(df['method'] == 'hst')].groupby(['percentage']).mean(numeric_only=True).reset_index()
df_hst
# Out:
#    percentage  precision    recall        f1
# 0          50   0.508925  0.178538  0.263689
# 1          60   0.411611  0.191550  0.260452
# 2          70   0.303935  0.215703  0.251613
# 3          80   0.204914  0.264438  0.229652
# 4          90   0.101802  0.420440  0.163562

# %%
plt.plot(df_z['percentage'], df_z['f1'], label='Z-Score')
plt.plot(df_lof['percentage'], df_lof['f1'], label='LOF')
plt.plot(df_if['percentage'], df_if['f1'], label='IForest')
plt.plot(df_hst['percentage'], df_hst['f1'], label='HST')
plt.title("F1-Score in outlier classification - NEWeather Dataset")
plt.legend()

# %%
plt.plot(df_z['percentage'], df_z['precision'], label='Z-Score')
plt.plot(df_lof['percentage'], df_lof['precision'], label='LOF')
plt.plot(df_if['percentage'], df_if['precision'], label='IForest')
plt.plot(df_hst['percentage'], df_hst['precision'], label='HST')
plt.title("F1-Score in outlier classification - NEWeather Dataset")
plt.legend()

# %%
plt.plot(df_z['percentage'], df_z['recall'], label='Z-Score')
plt.plot(df_lof['percentage'], df_lof['recall'], label='LOF')
plt.plot(df_if['percentage'], df_if['recall'], label='IForest')
plt.plot(df_hst['percentage'], df_hst['recall'], label='HST')
plt.title("F1-Score in outlier classification - NEWeather Dataset")
plt.legend()
