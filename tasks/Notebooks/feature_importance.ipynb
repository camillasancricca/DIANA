# %%
import matplotlib.pyplot as plt

fi_clean = [0.833,0.012,0.018,0.208,0.003,0.006,0.002,0.047,0,0.001,0.002,0.003]
fi_1 = [0.170,-0.008,-0.007,0.091,0.021,0.018,0.113,0.103,0,-0.001,0.020,0.005]
fi_2 = [0.195,0.017,0.022,0.141,0.034,0.061,0.052,0.115,0,0.031,0.016,0.003]
fi_3 = [0.242,0.022,0.018,0.147,0.061,0.027,0.082,0.130,0,0.027,0.009,0.004]
fi_4 = [0.231,0.011,0.010,0.106,0.084,0.044,0.046,0.112,0,0.019,0.020,0.005]
fi_5 = [0.248,0.008,0.015,0.126,0.064,0.034,0.077,0.139,0,0.008,0.013,0.002]

# %%
import math

d_1 = distance = math.sqrt(sum((x - y) ** 2 for x, y in zip(fi_clean, fi_1)))
d_1
# Out:
# 0.6859591824591313

# %%
d_2 = distance = math.sqrt(sum((x - y) ** 2 for x, y in zip(fi_clean, fi_2)))
d_2
# Out:
# 0.6509838707679322

# %%
d_3 = distance = math.sqrt(sum((x - y) ** 2 for x, y in zip(fi_clean, fi_3)))
d_3
# Out:
# 0.6090336608103036

# %%
d_4 = distance = math.sqrt(sum((x - y) ** 2 for x, y in zip(fi_clean, fi_4)))
d_4
# Out:
# 0.6226483758912408

# %%
d_5 = distance = math.sqrt(sum((x - y) ** 2 for x, y in zip(fi_clean, fi_5)))
d_5
# Out:
# 0.6064148744877552

# %%
import matplotlib.pyplot as plt
d = [d_1,d_2,d_3,d_4,d_5]
perc = [10,20,30,40,50]
plt.plot(perc,d)
